# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from torchvision.models import resnet34
import pickle
import numpy as np
import argparse
import os
from PIL import Image
import pandas as pd
import random

print("env is done")
# Out:
# env is done

# %% [markdown]
# #### 读取并打包ANIMAL-10N数据集

# %%
file_path = 'autodl-tmp/ANIMAL-10N'
# 训练数据
file_path = os.path.join(file_path,'testing')

# 测试数据
# file_path = os.path.join(file_path,'testing')

classesname_animal = {0: "Cat", 1: "Lynx", 2: "Wolf", 3: "Coyote", 4: "Cheetah", 5: "jaguar", 6: "Chimpanzee", 7: "Orangutan", 8: "Hamster", 9: "Guinea pig"}

images_animal = []
labels_animal = []

images_file = os.listdir(file_path)

for image_file in images_file:
    image_path = os.path.join(file_path,image_file)
    label = int(image_file[0])
    image = Image.open(image_path)
    image = image.convert('RGB')
    image = np.array(image)
    images_animal.append(image)
    labels_animal.append(label)

# %%
# 数据增强（训练集和测试集）
transforms_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transforms_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# 自定义 Dataset 类
class AnimalDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # 将图像转换为 PIL 格式
        image = Image.fromarray(np.array(self.images[idx]))  # 确保图像是 PIL 格式
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        
        if self.transform:
            image = self.transform(image)
            
        return image, label
    
length = len(images_animal)
# 将 20% 的数据作为训练集，剩余 80% 的数据作为测试集
# 设置随机种子以确保结果一致
random.seed(42)

# 将图像和标签组合起来进行打乱
data = list(zip(images_animal, labels_animal))
random.shuffle(data)

# 解压打乱后的数据
shuffled_images, shuffled_labels = zip(*data)

# 获取数据集的长度
length = len(shuffled_images)

# 划分训练集（20%）和测试集（80%）
trainset_animal = AnimalDataset(
    images=shuffled_images[:int(0.6 * length)], 
    labels=shuffled_labels[:int(0.6 * length)],
    transform=transforms_train
)
testset_animal = AnimalDataset(
    images=shuffled_images[int(0.6 * length):], 
    labels=shuffled_labels[int(0.6 * length):],
    transform=transforms_test
)

# %%
# 设置设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 256

train_loader = DataLoader(trainset_animal, batch_size=batch_size, shuffle=True, num_workers=4)
test_loader = DataLoader(testset_animal, batch_size=batch_size, shuffle=False, num_workers=4)

# %%
# 定义 ResNet 模型
def initialize_model(weights_path):
    model = resnet34(weights=None)
    model.fc = nn.Linear(model.fc.in_features, 10)
    if weights_path:
        state_dict = torch.load(weights_path)
        model.load_state_dict(state_dict, strict=False)
    return model.to(device)

# 定义损失函数和优化器
def initialize_optimizer(model):
    optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
    return optimizer, scheduler

# 训练函数
def train(model, train_loader, criterion, optimizer):
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets).mean()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
    
    avg_loss = running_loss / len(train_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# 测试函数
def test(model, test_loader, criterion):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets).mean()
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    
    avg_loss = running_loss / len(test_loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

# 创建文件夹
os.makedirs('log', exist_ok=True)
os.makedirs('weight', exist_ok=True)

# %%
print(f"-----------------直接训练开始，noise标签为 -----------------")
model = initialize_model('weight/resnet34_animal_raw_noisy_label.pth')
optimizer, scheduler = initialize_optimizer(model)

criterion = nn.CrossEntropyLoss(reduction='none')

train_losses, train_accuracies, test_losses, test_accuracies = [], [], [], []

epochs = 100
# 直接训练
for epoch in range(epochs):
    train_loss, train_accuracy = train(model, train_loader, criterion, optimizer)
    test_loss, test_accuracy = test(model, test_loader, criterion)
    scheduler.step()
        
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)

    print(f'Epoch {epoch + 1} - Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, '
            f'Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%')
    if train_accuracy > 99.999:
        break

# 保存训练日志
pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Train Loss': train_losses,
    'Train Accuracy': train_accuracies,
    'Test Loss': test_losses,
    'Test Accuracy': test_accuracies
}).to_csv(f'log//resnet34_animal_raw_finetuning_all', index=False)
    
torch.save(model.state_dict(), f'weight//resnet34_animal_raw_finetuning_all.pth')
print(f"训练过程已保存到 'log//resnet34_animal_raw_finetuning_all.csv'，模型权重保存为 'weight/resnet34_animal_raw_finetuning_all.pth'")
# Out:
# -----------------直接训练开始，noise标签为 -----------------
# Epoch 1 - Train Loss: 1.3602, Train Acc: 53.07%, Test Loss: 113.3831, Test Acc: 8.25%
# Epoch 2 - Train Loss: 1.4738, Train Acc: 48.10%, Test Loss: 6.9003, Test Acc: 17.85%
# Epoch 3 - Train Loss: 1.4425, Train Acc: 48.93%, Test Loss: 1.6779, Test Acc: 40.20%
# Epoch 4 - Train Loss: 1.3909, Train Acc: 50.83%, Test Loss: 1.6139, Test Acc: 41.15%
# Epoch 5 - Train Loss: 1.3879, Train Acc: 50.50%, Test Loss: 1.5007, Test Acc: 48.85%
# Epoch 6 - Train Loss: 1.3706, Train Acc: 51.73%, Test Loss: 1.5037, Test Acc: 50.05%
# Epoch 7 - Train Loss: 1.3579, Train Acc: 51.30%, Test Loss: 1.4559, Test Acc: 50.35%
# Epoch 8 - Train Loss: 1.3447, Train Acc: 52.93%, Test Loss: 1.5875, Test Acc: 44.25%
# Epoch 9 - Train Loss: 1.3653, Train Acc: 52.33%, Test Loss: 1.4823, Test Acc: 47.15%
# Epoch 10 - Train Loss: 1.3276, Train Acc: 53.13%, Test Loss: 1.5754, Test Acc: 45.00%
# Epoch 11 - Train Loss: 1.3072, Train Acc: 54.30%, Test Loss: 1.3797, Test Acc: 53.25%
# Epoch 12 - Train Loss: 1.3163, Train Acc: 53.93%, Test Loss: 1.4615, Test Acc: 49.35%
# Epoch 13 - Train Loss: 1.2789, Train Acc: 54.30%, Test Loss: 1.4455, Test Acc: 50.15%
# Epoch 14 - Train Loss: 1.3497, Train Acc: 52.20%, Test Loss: 1.5864, Test Acc: 46.75%
# Epoch 15 - Train Loss: 1.3073, Train Acc: 53.60%, Test Loss: 1.4712, Test Acc: 51.65%
# Epoch 16 - Train Loss: 1.2846, Train Acc: 55.10%, Test Loss: 1.3914, Test Acc: 52.90%
# Epoch 17 - Train Loss: 1.2854, Train Acc: 55.30%, Test Loss: 1.4052, Test Acc: 50.60%
# Epoch 18 - Train Loss: 1.2787, Train Acc: 54.27%, Test Loss: 1.4654, Test Acc: 49.50%
# Epoch 19 - Train Loss: 1.2724, Train Acc: 54.27%, Test Loss: 1.3870, Test Acc: 52.00%
# Epoch 20 - Train Loss: 1.3072, Train Acc: 54.33%, Test Loss: 1.3983, Test Acc: 53.25%
# Epoch 21 - Train Loss: 1.2829, Train Acc: 54.57%, Test Loss: 1.4121, Test Acc: 53.10%
# Epoch 22 - Train Loss: 1.2553, Train Acc: 55.67%, Test Loss: 1.4070, Test Acc: 53.45%
# Epoch 23 - Train Loss: 1.2760, Train Acc: 55.23%, Test Loss: 1.4276, Test Acc: 51.05%
# Epoch 24 - Train Loss: 1.2636, Train Acc: 55.17%, Test Loss: 1.4063, Test Acc: 52.70%
# Epoch 80 - Train Loss: 0.8377, Train Acc: 70.73%, Test Loss: 1.0830, Test Acc: 65.05%
# Epoch 81 - Train Loss: 0.8116, Train Acc: 71.53%, Test Loss: 1.0809, Test Acc: 65.40%
# Epoch 82 - Train Loss: 0.8580, Train Acc: 69.37%, Test Loss: 1.0974, Test Acc: 64.30%
# Epoch 83 - Train Loss: 0.8279, Train Acc: 71.20%, Test Loss: 1.0914, Test Acc: 64.80%
# Epoch 84 - Train Loss: 0.8319, Train Acc: 70.70%, Test Loss: 1.0893, Test Acc: 65.25%
# Epoch 85 - Train Loss: 0.8617, Train Acc: 69.97%, Test Loss: 1.0828, Test Acc: 65.05%
# Epoch 86 - Train Loss: 0.8129, Train Acc: 71.77%, Test Loss: 1.0946, Test Acc: 64.75%
# Epoch 87 - Train Loss: 0.8496, Train Acc: 69.93%, Test Loss: 1.0998, Test Acc: 64.75%
# Epoch 88 - Train Loss: 0.8293, Train Acc: 71.30%, Test Loss: 1.0877, Test Acc: 65.05%
# Epoch 89 - Train Loss: 0.8286, Train Acc: 70.57%, Test Loss: 1.0791, Test Acc: 65.35%
# Epoch 90 - Train Loss: 0.8087, Train Acc: 71.13%, Test Loss: 1.0782, Test Acc: 65.25%
# Epoch 91 - Train Loss: 0.8265, Train Acc: 70.97%, Test Loss: 1.0780, Test Acc: 65.30%
# Epoch 92 - Train Loss: 0.8324, Train Acc: 70.97%, Test Loss: 1.0755, Test Acc: 65.30%
# Epoch 93 - Train Loss: 0.8420, Train Acc: 71.10%, Test Loss: 1.0808, Test Acc: 65.10%
# Epoch 94 - Train Loss: 0.8290, Train Acc: 71.10%, Test Loss: 1.0768, Test Acc: 65.40%
# Epoch 95 - Train Loss: 0.8679, Train Acc: 69.63%, Test Loss: 1.0722, Test Acc: 65.75%
# Epoch 96 - Train Loss: 0.8185, Train Acc: 71.43%, Test Loss: 1.0699, Test Acc: 65.80%
# Epoch 97 - Train Loss: 0.8266, Train Acc: 70.20%, Test Loss: 1.0784, Test Acc: 65.15%
# Epoch 98 - Train Loss: 0.8117, Train Acc: 72.00%, Test Loss: 1.0705, Test Acc: 65.70%
# Epoch 99 - Train Loss: 0.8237, Train Acc: 70.87%, Test Loss: 1.0834, Test Acc: 65.15%
# Epoch 100 - Train Loss: 0.8099, Train Acc: 72.00%, Test Loss: 1.0738, Test Acc: 65.70%
# 训练过程已保存到 'log//resnet34_animal_raw_finetuning_all.csv'，模型权重保存为 'weight/resnet34_animal_raw_finetuning_all.pth'

# %%
print(f"-----------------输出层fine-tuning -----------------")
model = initialize_model('weight/resnet34_animal_raw_noisy_label.pth')

# 冻结所有参数（不计算梯度）
for param in model.parameters():
    param.requires_grad = False

# 仅对最后一层（model.fc）的参数解冻
for param in model.fc.parameters():
    param.requires_grad = True

# 仅将最后一层的参数传递给优化器
optimizer, scheduler = initialize_optimizer(model)

lr = 0.1
optimizer = optim.SGD(model.fc.parameters(), lr=lr, momentum=0.9)

criterion = nn.CrossEntropyLoss(reduction='none')

train_losses, train_accuracies, test_losses, test_accuracies = [], [], [], []

epochs = 100
# 直接训练
for epoch in range(epochs):
    train_loss, train_accuracy = train(model, train_loader, criterion, optimizer)
    test_loss, test_accuracy = test(model, test_loader, criterion)
    scheduler.step()
        
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)

    print(f'Epoch {epoch + 1} - Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, '
            f'Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%')
    if train_accuracy > 99.999:
        break

# 保存训练日志
pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Train Loss': train_losses,
    'Train Accuracy': train_accuracies,
    'Test Loss': test_losses,
    'Test Accuracy': test_accuracies
}).to_csv(f'log//resnet34_animal_raw_finetuning_{lr}fc.csv', index=False)
    
torch.save(model.state_dict(), f'weight//resnet34_animal_raw_finetuning_{lr}fc.pth')
print(f"训练过程已保存到 'log//resnet34_animal_raw_finetuning_{lr}fc.csv'，模型权重保存为 'weight/resnet34_animal_raw_finetuning_{lr}fc.pth'")
# Out:
# -----------------输出层fine-tuning -----------------
# Epoch 1 - Train Loss: 1.0341, Train Acc: 64.53%, Test Loss: 1.3811, Test Acc: 63.45%
# Epoch 2 - Train Loss: 1.0215, Train Acc: 64.03%, Test Loss: 1.2596, Test Acc: 67.40%
# Epoch 3 - Train Loss: 1.0358, Train Acc: 63.70%, Test Loss: 1.3040, Test Acc: 65.15%
# Epoch 4 - Train Loss: 1.0220, Train Acc: 63.87%, Test Loss: 1.3896, Test Acc: 63.55%
# Epoch 5 - Train Loss: 0.9994, Train Acc: 64.43%, Test Loss: 1.2732, Test Acc: 65.95%
# Epoch 6 - Train Loss: 1.0465, Train Acc: 62.83%, Test Loss: 1.2744, Test Acc: 65.05%
# Epoch 7 - Train Loss: 0.9966, Train Acc: 65.30%, Test Loss: 1.2900, Test Acc: 65.65%
# Epoch 8 - Train Loss: 1.0352, Train Acc: 64.83%, Test Loss: 1.2886, Test Acc: 65.60%
# Epoch 9 - Train Loss: 0.9854, Train Acc: 64.87%, Test Loss: 1.2068, Test Acc: 68.40%
# Epoch 10 - Train Loss: 1.0343, Train Acc: 63.80%, Test Loss: 1.3395, Test Acc: 64.15%
# Epoch 11 - Train Loss: 1.0166, Train Acc: 64.47%, Test Loss: 1.3298, Test Acc: 65.40%
# Epoch 12 - Train Loss: 1.0253, Train Acc: 65.03%, Test Loss: 1.2427, Test Acc: 66.20%
# Epoch 13 - Train Loss: 1.0251, Train Acc: 63.47%, Test Loss: 1.2578, Test Acc: 66.20%
# Epoch 14 - Train Loss: 1.0438, Train Acc: 63.43%, Test Loss: 1.2950, Test Acc: 65.25%
# Epoch 15 - Train Loss: 1.0474, Train Acc: 63.60%, Test Loss: 1.3285, Test Acc: 63.90%
# Epoch 16 - Train Loss: 0.9890, Train Acc: 65.50%, Test Loss: 1.2289, Test Acc: 67.45%
# Epoch 17 - Train Loss: 1.0233, Train Acc: 63.87%, Test Loss: 1.2394, Test Acc: 67.05%
# Epoch 18 - Train Loss: 1.0153, Train Acc: 65.07%, Test Loss: 1.2889, Test Acc: 65.55%
# Epoch 19 - Train Loss: 1.0262, Train Acc: 64.53%, Test Loss: 1.2864, Test Acc: 66.55%
# Epoch 20 - Train Loss: 1.0278, Train Acc: 63.57%, Test Loss: 1.2357, Test Acc: 67.20%
# Epoch 21 - Train Loss: 1.0228, Train Acc: 63.93%, Test Loss: 1.3156, Test Acc: 65.55%
# Epoch 22 - Train Loss: 1.0073, Train Acc: 64.77%, Test Loss: 1.2808, Test Acc: 65.60%
# Epoch 23 - Train Loss: 1.0080, Train Acc: 64.13%, Test Loss: 1.3105, Test Acc: 65.05%
# Epoch 24 - Train Loss: 1.0189, Train Acc: 64.43%, Test Loss: 1.3322, Test Acc: 64.90%
# Epoch 25 - Train Loss: 1.0115, Train Acc: 64.50%, Test Loss: 1.3089, Test Acc: 64.90%
# Epoch 26 - Train Loss: 0.9950, Train Acc: 64.07%, Test Loss: 1.3078, Test Acc: 65.65%
# Epoch 27 - Train Loss: 0.9899, Train Acc: 66.07%, Test Loss: 1.2739, Test Acc: 65.60%
# Epoch 28 - Train Loss: 1.0101, Train Acc: 64.83%, Test Loss: 1.2168, Test Acc: 67.35%
# Epoch 29 - Train Loss: 1.0048, Train Acc: 64.97%, Test Loss: 1.2947, Test Acc: 65.25%
# Epoch 30 - Train Loss: 1.0497, Train Acc: 63.30%, Test Loss: 1.2681, Test Acc: 65.50%
# Epoch 31 - Train Loss: 0.9928, Train Acc: 65.37%, Test Loss: 1.2714, Test Acc: 65.90%
# Epoch 32 - Train Loss: 1.0161, Train Acc: 64.67%, Test Loss: 1.2577, Test Acc: 66.70%
# Epoch 33 - Train Loss: 1.0210, Train Acc: 64.20%, Test Loss: 1.3176, Test Acc: 64.90%
# Epoch 34 - Train Loss: 1.0350, Train Acc: 63.57%, Test Loss: 1.3566, Test Acc: 64.25%
# Epoch 35 - Train Loss: 1.0026, Train Acc: 64.50%, Test Loss: 1.2727, Test Acc: 65.95%
# Epoch 36 - Train Loss: 1.0023, Train Acc: 64.27%, Test Loss: 1.3413, Test Acc: 63.75%
# Epoch 37 - Train Loss: 1.0264, Train Acc: 63.60%, Test Loss: 1.2539, Test Acc: 67.20%
# Epoch 38 - Train Loss: 1.0423, Train Acc: 63.50%, Test Loss: 1.2870, Test Acc: 65.20%
# Epoch 39 - Train Loss: 1.0314, Train Acc: 63.83%, Test Loss: 1.3004, Test Acc: 65.30%
# Epoch 40 - Train Loss: 0.9968, Train Acc: 64.37%, Test Loss: 1.2891, Test Acc: 66.10%
# Epoch 41 - Train Loss: 1.0142, Train Acc: 64.20%, Test Loss: 1.2638, Test Acc: 66.30%
# Epoch 42 - Train Loss: 1.0122, Train Acc: 63.67%, Test Loss: 1.2513, Test Acc: 66.05%
# Epoch 43 - Train Loss: 1.0130, Train Acc: 64.90%, Test Loss: 1.2486, Test Acc: 66.60%
# Epoch 44 - Train Loss: 0.9725, Train Acc: 64.83%, Test Loss: 1.1935, Test Acc: 68.40%
# Epoch 45 - Train Loss: 1.0166, Train Acc: 64.73%, Test Loss: 1.2829, Test Acc: 64.10%
# Epoch 46 - Train Loss: 1.0305, Train Acc: 64.93%, Test Loss: 1.1908, Test Acc: 68.30%
# Epoch 47 - Train Loss: 1.0226, Train Acc: 64.37%, Test Loss: 1.2524, Test Acc: 66.05%
# Epoch 48 - Train Loss: 1.0050, Train Acc: 64.83%, Test Loss: 1.2628, Test Acc: 66.15%
# Epoch 49 - Train Loss: 0.9854, Train Acc: 65.87%, Test Loss: 1.2121, Test Acc: 67.00%
# Epoch 50 - Train Loss: 1.0049, Train Acc: 64.87%, Test Loss: 1.2010, Test Acc: 67.75%
# Epoch 51 - Train Loss: 0.9990, Train Acc: 65.20%, Test Loss: 1.2074, Test Acc: 67.45%
# Epoch 52 - Train Loss: 1.0188, Train Acc: 64.43%, Test Loss: 1.2991, Test Acc: 65.20%
# Epoch 53 - Train Loss: 1.0289, Train Acc: 63.67%, Test Loss: 1.3073, Test Acc: 64.80%
# Epoch 54 - Train Loss: 0.9887, Train Acc: 65.13%, Test Loss: 1.3006, Test Acc: 65.05%
# Epoch 55 - Train Loss: 0.9932, Train Acc: 65.33%, Test Loss: 1.2637, Test Acc: 66.00%
# Epoch 56 - Train Loss: 1.0233, Train Acc: 64.17%, Test Loss: 1.2926, Test Acc: 64.85%
# Epoch 57 - Train Loss: 0.9925, Train Acc: 64.83%, Test Loss: 1.2883, Test Acc: 64.50%
# Epoch 58 - Train Loss: 1.0240, Train Acc: 64.17%, Test Loss: 1.2289, Test Acc: 67.15%
# Epoch 59 - Train Loss: 0.9790, Train Acc: 66.00%, Test Loss: 1.3215, Test Acc: 63.25%
# Epoch 60 - Train Loss: 1.0127, Train Acc: 64.80%, Test Loss: 1.3027, Test Acc: 64.30%
# Epoch 61 - Train Loss: 1.0108, Train Acc: 65.57%, Test Loss: 1.3113, Test Acc: 64.95%
# Epoch 62 - Train Loss: 1.0104, Train Acc: 64.80%, Test Loss: 1.2517, Test Acc: 66.45%
# Epoch 63 - Train Loss: 1.0155, Train Acc: 64.63%, Test Loss: 1.2708, Test Acc: 64.35%
# Epoch 64 - Train Loss: 1.0136, Train Acc: 65.10%, Test Loss: 1.2586, Test Acc: 66.95%
# Epoch 65 - Train Loss: 1.0264, Train Acc: 63.30%, Test Loss: 1.2323, Test Acc: 67.10%
# Epoch 66 - Train Loss: 1.0186, Train Acc: 64.53%, Test Loss: 1.3206, Test Acc: 64.70%
# Epoch 67 - Train Loss: 1.0158, Train Acc: 63.97%, Test Loss: 1.2962, Test Acc: 64.95%
# Epoch 68 - Train Loss: 1.0012, Train Acc: 64.97%, Test Loss: 1.3100, Test Acc: 64.45%
# Epoch 69 - Train Loss: 1.0020, Train Acc: 64.37%, Test Loss: 1.3535, Test Acc: 62.60%
# Epoch 70 - Train Loss: 0.9949, Train Acc: 65.83%, Test Loss: 1.3363, Test Acc: 64.15%
# Epoch 71 - Train Loss: 0.9939, Train Acc: 65.23%, Test Loss: 1.3078, Test Acc: 63.50%
# Epoch 72 - Train Loss: 1.0152, Train Acc: 65.27%, Test Loss: 1.2920, Test Acc: 65.10%
# Epoch 73 - Train Loss: 1.0247, Train Acc: 63.87%, Test Loss: 1.3858, Test Acc: 61.45%
# Epoch 74 - Train Loss: 1.0147, Train Acc: 63.40%, Test Loss: 1.2675, Test Acc: 65.65%
# Epoch 75 - Train Loss: 1.0086, Train Acc: 64.33%, Test Loss: 1.2678, Test Acc: 65.25%
# Epoch 76 - Train Loss: 1.0205, Train Acc: 64.20%, Test Loss: 1.2978, Test Acc: 64.70%
# Epoch 77 - Train Loss: 0.9915, Train Acc: 64.83%, Test Loss: 1.2578, Test Acc: 65.65%
# Epoch 78 - Train Loss: 1.0092, Train Acc: 64.17%, Test Loss: 1.2110, Test Acc: 66.75%
# Epoch 79 - Train Loss: 1.0239, Train Acc: 65.07%, Test Loss: 1.3334, Test Acc: 63.00%
# Epoch 80 - Train Loss: 0.9887, Train Acc: 65.40%, Test Loss: 1.2405, Test Acc: 67.10%
# Epoch 81 - Train Loss: 1.0058, Train Acc: 64.90%, Test Loss: 1.3189, Test Acc: 63.90%
# Epoch 82 - Train Loss: 1.0258, Train Acc: 63.30%, Test Loss: 1.2520, Test Acc: 65.30%
# Epoch 83 - Train Loss: 0.9887, Train Acc: 65.33%, Test Loss: 1.2983, Test Acc: 63.30%
# Epoch 84 - Train Loss: 1.0085, Train Acc: 64.23%, Test Loss: 1.2450, Test Acc: 66.85%
# Epoch 85 - Train Loss: 1.0136, Train Acc: 64.63%, Test Loss: 1.3061, Test Acc: 63.75%
# Epoch 86 - Train Loss: 1.0055, Train Acc: 64.03%, Test Loss: 1.2587, Test Acc: 65.55%
# Epoch 87 - Train Loss: 1.0308, Train Acc: 63.57%, Test Loss: 1.2689, Test Acc: 66.15%
# Epoch 88 - Train Loss: 1.0136, Train Acc: 63.20%, Test Loss: 1.2227, Test Acc: 67.05%
# Epoch 89 - Train Loss: 1.0265, Train Acc: 64.50%, Test Loss: 1.2785, Test Acc: 65.80%
# Epoch 90 - Train Loss: 1.0032, Train Acc: 65.23%, Test Loss: 1.2354, Test Acc: 66.10%
# Epoch 91 - Train Loss: 1.0055, Train Acc: 63.57%, Test Loss: 1.2217, Test Acc: 67.75%
# Epoch 92 - Train Loss: 0.9904, Train Acc: 64.50%, Test Loss: 1.2902, Test Acc: 64.30%
# Epoch 93 - Train Loss: 1.0252, Train Acc: 63.93%, Test Loss: 1.3156, Test Acc: 64.10%
# Epoch 94 - Train Loss: 1.0218, Train Acc: 64.30%, Test Loss: 1.2201, Test Acc: 66.00%
# Epoch 95 - Train Loss: 1.0096, Train Acc: 65.17%, Test Loss: 1.2950, Test Acc: 64.60%
# Epoch 96 - Train Loss: 0.9949, Train Acc: 64.87%, Test Loss: 1.2509, Test Acc: 66.50%
# Epoch 97 - Train Loss: 0.9828, Train Acc: 65.00%, Test Loss: 1.2412, Test Acc: 66.50%
# Epoch 98 - Train Loss: 0.9955, Train Acc: 65.00%, Test Loss: 1.3055, Test Acc: 62.95%
# Epoch 99 - Train Loss: 1.0073, Train Acc: 63.97%, Test Loss: 1.2409, Test Acc: 66.90%
# Epoch 100 - Train Loss: 0.9901, Train Acc: 64.43%, Test Loss: 1.2726, Test Acc: 65.55%
# 训练过程已保存到 'log//resnet34_animal_raw_finetuning_0.1fc.csv'，模型权重保存为 'weight/resnet34_animal_raw_finetuning_0.1fc.pth'
